# %% [markdown]
# ## DEMOGRAPHIC INFORMATION OF STUDENTS

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
firstIndexes=["Gender","Gender","Gender",
              "Educational Status","Educational Status","Educational Status","Educational Status",
              "Average Daily Computer/Internet Usage Time","Average Daily Computer/Internet Usage Time",
              "Average Daily Computer/Internet Usage Time","Average Daily Computer/Internet Usage Time"]

# %%
internalIndexes=["Male","Woman","Total","High school","Associate Degree",
                 "Licence","Total","0-2 Hours","3-5 Hours","9 Hours and above","Total"]

# %%
combinedIndexes=list(zip(firstIndexes,internalIndexes))
combinedIndexes

# %%
combinedIndexes=pd.MultiIndex.from_tuples(combinedIndexes)
combinedIndexes

# %%
firstList=[[476,54.7],[394,45.3],[870,100],[371,42.6],[212,24.4],[287,33.0],
           [870,100],[482,55.4],[314,36.1],[74,8.1],[870,100]]

# %%
numpyList=np.array(firstList)

# %%
dataFrameList=pd.DataFrame(numpyList,index=combinedIndexes,columns=["f","%"])

# %%
dataFrameList
# Out:
#                                                                   f      %
# Variable                                   Category
# Gender                                     Male               476.0   54.7
#                                            Woman              394.0   45.3
#                                            Total              870.0  100.0
# Educational Status                         High school        371.0   42.6
#                                            Associate Degree   212.0   24.4
#                                            Licence            287.0   33.0
#                                            Total              870.0  100.0
# Average Daily Computer/Internet Usage Time 0-2 Hours          482.0   55.4
#                                            3-5 Hours          314.0   36.1
#                                            9 Hours and above   74.0    8.1
#                                            Total              870.0  100.0

# %%
dataFrameList.index.names=["Variable","Category"]

# %%
dataFrameList
# Out:
#                                                                   f      %
# Variable                                   Category
# Gender                                     Male               476.0   54.7
#                                            Woman              394.0   45.3
#                                            Total              870.0  100.0
# Educational Status                         High school        371.0   42.6
#                                            Associate Degree   212.0   24.4
#                                            Licence            287.0   33.0
#                                            Total              870.0  100.0
# Average Daily Computer/Internet Usage Time 0-2 Hours          482.0   55.4
#                                            3-5 Hours          314.0   36.1
#                                            9 Hours and above   74.0    8.1
#                                            Total              870.0  100.0

# %%
fig, (graph1, graph2, graph3) = plt.subplots(1, 3, figsize=(15, 5))

categories = ['Male', 'Woman']
graph1.bar(categories,[476,394],color="#899AB1")
graph1.set_xlabel("GENDER")
graph1.set_ylabel("NUMBER OF PEOPLE")
graph1.set_title("AI LITERACY GRAPH-NUMBER OF MEN AND WOMEN")

categories = ['High school', 'Associate Degree',"Licence"]
graph2.bar(categories,[371,212,287],color="#3A95A8")
graph2.set_xlabel("EDUCATIONAL STATUS")
graph2.set_ylabel("NUMBER OF PEOPLE")
graph2.set_title("AI LITERACY GRAPH-EDUCATIONAL STATUS NUMBER OF PEOPLE")

categories = ['0-2 Hours', '3-5 Hours',"9 Hours and above"]
graph3.bar(categories,[482,314,74],color="#005B82")
graph3.set_xlabel("AVERAGE DAILY COMPUTER/ INTERNET USAGE TIME")
graph3.set_ylabel("NUMBER OF PEOPLE")
graph3.set_title("AI LITERACY GRAPH-AVERAGE DAILY USAGE TIME")

plt.tight_layout()

# %%
fig, (graph1, graph2, graph3) = plt.subplots(1, 3, figsize=(15, 5))

categories = ['Male', 'Woman']
graph1.bar(categories,[54.7,45.3],color="#899AB1")
graph1.set_xlabel("GENDER")
graph1.set_ylabel("PERCENTAGES")
graph1.set_title("AI L. GRAPH-PERCENTAGE OF MALE AND FEMALE")

categories = ['High school', 'Associate Degree',"Licence"]
graph2.bar(categories,[42.6,24.4,33.0],color="#3A95A8")
graph2.set_xlabel("EDUCATIONAL STATUS")
graph2.set_ylabel("PERCENTAGES")
graph2.set_title("AI L. GRAPH-EDUCATION STATUS PERSON PERCENTAGE")

categories = ['0-2 Hours', '3-5 Hours',"9 Hours and above"]
graph3.bar(categories,[55.4,36.1,8.1],color="#005B82")
graph3.set_xlabel("AVERAGE DAILY COMPUTER/ INTERNET USAGE TIME")
graph3.set_ylabel("PERCENTAGES")
graph3.set_title("AI L. GRAPH-AVERAGE DAILY USAGE PERCENTAGE")

plt.tight_layout()
